# %% [markdown]
# <a href="https://colab.research.google.com/github/KuproyMalang/PCVK_Genap_2023/blob/main/tubes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import cv2 as cv
from google.colab.patches import cv2_imshow


# Load the Haar Cascade file for detecting face
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade/haarcascade_frontalface_default.xml')

# Load the image file
img = cv.imread('/content/drive/MyDrive/muka.jpeg')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# Detect faces in the image
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# Draw rectangles around the detected faces
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

# Show the result
cv2_imshow(img)
cv.waitKey(0)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=197x197 at 0x7F021F116830>
# -1

# %%
from google.colab import drive
drive.mount('/content/drive')
import cv2 as cv
from google.colab.patches import cv2_imshow


# Load the Haar Cascade file for detecting face
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade/haarcascade_eye.xml')

# Load the image file
img = cv.imread('/content/drive/MyDrive/muka.jpeg')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# Detect faces in the image
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# Draw rectangles around the detected faces
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

# Show the result
cv2_imshow(img)
cv.waitKey(0)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=197x197 at 0x7F02117D2740>
# -1
